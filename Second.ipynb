# %%
import pandas
import json as js

# %%
df = pandas.read_csv('LMS-DataStuff/pg_catalog.csv')

# %%
'get shape of data'

print(df.shape)
# Out:
# (76135, 9)

# %%
"get comprehensive info on dataset"

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 76135 entries, 0 to 76134
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Text#        76135 non-null  int64
#  1   Type         76135 non-null  str
#  2   Issued       76135 non-null  str
#  3   Title        76135 non-null  str
#  4   Language     76135 non-null  str
#  5   Authors      75970 non-null  str
#  6   Subjects     76066 non-null  str
#  7   LoCC         75859 non-null  str
#  8   Bookshelves  75862 non-null  str
# dtypes: int64(1), str(8)
# memory usage: 5.2 MB
# None
