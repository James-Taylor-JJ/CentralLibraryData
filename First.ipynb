# %%
import pandas
import json

# %%
pandas.read_csv("./LMS-DataStuff/pg_catalog.csv")
# Out:
#        Text#  Type      Issued  \
# 0          1  Text  1971-12-01
# 1          2  Text  1972-12-01
# 2          3  Text  1973-11-01
# 3          4  Text  1973-11-01
# 4          5  Text  1975-12-01
# ...      ...   ...         ...
# 76130  76310  Text  2025-06-15
# 76131  76311  Text  2025-06-15
# 76132  76312  Text  2025-06-15
# 76133  76313  Text  2025-06-15
# 76134  76314  Text  2025-06-15
#
#                                                    Title Language  \
# 0      The Declaration of Independence of the United ...       en
# 1      The United States Bill of Rights\r\nThe Ten Or...       en
# 2                    John F. Kennedy's Inaugural Address       en
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en
# 4                         The United States Constitution       en
# ...                                                  ...      ...
# 76130                                         Cindrulino       eo
# ...

# %%
pandas.read_csv("LMS-DataStuff/tcc_ceds_music.csv")
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/credits.csv")
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/keywords.csv")
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/links_small.csv")
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0
#
# [9125 rows x 3 columns]

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/links.csv")
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/movies_metadata.csv")
# Out:
# /var/folders/f_/93v_b49109x0tkj367ph296m0000gp/T/ipykernel_36151/3095774179.py:1: DtypeWarning: Columns (0: popularity) have mixed types. Specify dtype option on import or set low_memory=False.
#   pandas.read_csv("LMS-DataStuff/movies-archive/movies_metadata.csv")
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# ...

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/ratings_small.csv")
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/ratings.csv")
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/merge_preview.csv")
# Out:
# /var/folders/f_/93v_b49109x0tkj367ph296m0000gp/T/ipykernel_17120/2932089626.py:1: DtypeWarning: Columns (0: tmdb_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   pandas.read_csv("LMS-DataStuff/movies-archive/merge_preview.csv")
#         movieId  tmdb_id    imdb_id                                title  \
# 0           NaN      100  tt0120735  Lock, Stock and Two Smoking Barrels
# 1        2542.0    100.0        NaN                                  NaN
# 2           NaN    10000  tt0109747            La estrategia del caracol
# 3       68168.0  10000.0        NaN                                  NaN
# 4           NaN    10001  tt0096486                       Young Einstein
# ...         ...      ...        ...                                  ...
# 91026       NaN  99977.0  tt0079308                            Hot Stuff
# 91027  117519.0  99977.0        NaN                                  NaN
# ...

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/movies_data_part1.csv")
# Out:
#         movieId  tmdb_id    imdb_id                                title  \
# 0           NaN      100  tt0120735  Lock, Stock and Two Smoking Barrels
# 1        2542.0    100.0        NaN                                  NaN
# 2           NaN    10000  tt0109747            La estrategia del caracol
# 3       68168.0  10000.0        NaN                                  NaN
# 4           NaN    10001  tt0096486                       Young Einstein
# ...         ...      ...        ...                                  ...
# 45510       NaN    31395  tt0109376               Car 54, Where Are You?
# 45511    7189.0  31395.0        NaN                                  NaN
# 45512       NaN    31396  tt0058311        Hercules Against the Moon Men
# 45513  146491.0  31396.0        NaN                                  NaN
# 45514       NaN    31397  tt0092532                      Alien from L.A.
#
#       collection                                           overview  runtime  \
# ...

# %%
pandas.read_csv("LMS-DataStuff/movies-archive/movies_data_section1.csv")
# Out:
#         movieId   tmdb_id    imdb_id                                title  \
# 0           NaN     100.0  tt0120735  Lock, Stock and Two Smoking Barrels
# 1        2542.0     100.0        NaN                                  NaN
# 2           NaN   10000.0  tt0109747            La estrategia del caracol
# 3       68168.0   10000.0        NaN                                  NaN
# 4           NaN   10001.0  tt0096486                       Young Einstein
# ...         ...       ...        ...                                  ...
# 24995       NaN   19725.0  tt0103927                    Carry On Columbus
# 24996  139461.0   19725.0        NaN                                  NaN
# 24997       NaN   19727.0  tt1203523                     Streets of Blood
# 24998   70064.0   19727.0        NaN                                  NaN
# 24999       NaN  197276.0  tt2649274                       The Ghost Army
#
#                                               collection  \
# ...

# %%
pandas.read_csv("LMS-DataStuff/trove-periodicals-data-main/periodical-issues.csv")
# Out:
#                       id           title_id  \
# 0        nla.obj-8447243    nla.obj-8423556
# 1        nla.obj-8452230    nla.obj-8423556
# 2        nla.obj-8458012    nla.obj-8423556
# 3        nla.obj-8465575    nla.obj-8423556
# 4        nla.obj-8469716    nla.obj-8423556
# ...                  ...                ...
# 37010  nla.obj-490481414  nla.obj-489106103
# 37011  nla.obj-490492247  nla.obj-489106103
# 37012  nla.obj-490512490  nla.obj-489106103
# 37013  nla.obj-490513884  nla.obj-489106103
# 37014  nla.obj-490602519  nla.obj-489106103
#
#                                                    title        description  \
# 0      "Coo-ee!" : the journal of the Bishops Knoll H...  Volume 1 Number 1
# 1      "Coo-ee!" : the journal of the Bishops Knoll H...  Volume 1 Number 2
# 2      "Coo-ee!" : the journal of the Bishops Knoll H...  Volume 1 Number 3
# 3      "Coo-ee!" : the journal of the Bishops Knoll H...  Volume 1 Number 4
# ...

# %%
pandas.read_csv("LMS-DataStuff/trove-periodicals-data-main/periodical-titles.csv")
# Out:
#                      id                                              title  \
# 0       nla.obj-8423556  "Coo-ee!" : the journal of the Bishops Knoll H...
# 1    nla.obj-2998991958  (Ross's) Hobart Town almanack, and Van Diemen'...
# 2    nla.obj-2998997061  (Ross's) Van Diemen's Land annual and Hobart T...
# 3      nla.obj-15956697                             14th Company magazine.
# 4     nla.obj-250818955        20 favourite & war-time camp songs [music].
# ..                  ...                                                ...
# 903    nla.obj-54933471                                            [Acts].
# 904  nla.obj-3193629693                    [Australian medical pamphlets].
# 905   nla.obj-773155481                                         [Magazine]
# 906   nla.obj-526663409                                         [Magazine]
# 907   nla.obj-489106103  [Program &] abstracts [book] : [NSW Coastal Co...
#
#     description                                publisher  \
# ...

# %%
pandas.read_json("LMS-DataStuff/trove-periodicals-data-main/metadata.json")
# Out:
#                                     title  \
# periodicals  GLAM Workbench Data Explorer
#
#                                                    description  \
# periodicals  Explore Trove's collection of digitised period...
#
#                              source  \
# periodicals  trove-periodicals-data
#
#                                                     source_url  \
# periodicals  https://github.com/GLAM-Workbench/trove-period...
#
#                                                      databases
# periodicals  {'tables': {'titles': {'sort': 'title', 'searc...

# %%
pandas.read_json("LMS-DataStuff/trove-periodicals-data-main/periodical-issues-schema.json")
# Out:
#                                               fields
# 0  {'name': 'id', 'type': 'string', 'description'...
# 1  {'name': 'title_id', 'type': 'string', 'descri...
# 2  {'name': 'title', 'type': 'string', 'descripti...
# 3  {'name': 'description', 'type': 'string', 'des...
# 4  {'name': 'date', 'type': 'date', 'description'...
# 5  {'name': 'url', 'type': 'string', 'description...
# 6  {'name': 'pages', 'type': 'integer', 'descript...
# 7  {'name': 'text_download_url', 'type': 'string'...

# %%
pandas.read_json("LMS-DataStuff/trove-periodicals-data-main/periodical-titles-schema.json")
# Out:
#                                                fields
# 0   {'name': 'id', 'type': 'string', 'description'...
# 1   {'name': 'title', 'type': 'string', 'descripti...
# 2   {'name': 'description', 'type': 'string', 'des...
# 3   {'name': 'publisher', 'type': 'string', 'descr...
# 4   {'name': 'trove_url', 'type': 'string', 'descr...
# 5   {'name': 'download_text', 'type': 'string', 'd...
# 6   {'name': 'issue_count', 'type': 'integer', 'de...
# 7   {'name': 'start_date', 'type': 'date', 'descri...
# 8   {'name': 'end_date', 'type': 'date', 'descript...
# 9   {'name': 'start_year', 'type': 'integer', 'des...
# 10  {'name': 'end_year', 'type': 'integer', 'descr...
# 11  {'name': 'extent', 'type': 'string', 'descript...
# 12  {'name': 'place', 'type': 'string', 'descripti...
# 13  {'name': 'issn', 'type': 'string', 'descriptio...
# 14  {'name': 'catalogue_url', 'type': 'string', 'd...

# %%
pandas.read_json("LMS-DataStuff/trove-periodicals-data-main/ro-crate-metadata.json")
# Out:
#                                  @context  \
# 0   https://w3id.org/ro/crate/1.1/context
# 1   https://w3id.org/ro/crate/1.1/context
# 2   https://w3id.org/ro/crate/1.1/context
# 3   https://w3id.org/ro/crate/1.1/context
# 4   https://w3id.org/ro/crate/1.1/context
# 5   https://w3id.org/ro/crate/1.1/context
# 6   https://w3id.org/ro/crate/1.1/context
# 7   https://w3id.org/ro/crate/1.1/context
# 8   https://w3id.org/ro/crate/1.1/context
# 9   https://w3id.org/ro/crate/1.1/context
# 10  https://w3id.org/ro/crate/1.1/context
# 11  https://w3id.org/ro/crate/1.1/context
# 12  https://w3id.org/ro/crate/1.1/context
# 13  https://w3id.org/ro/crate/1.1/context
# 14  https://w3id.org/ro/crate/1.1/context
# 15  https://w3id.org/ro/crate/1.1/context
# 16  https://w3id.org/ro/crate/1.1/context
# 17  https://w3id.org/ro/crate/1.1/context
# 18  https://w3id.org/ro/crate/1.1/context
# 19  https://w3id.org/ro/crate/1.1/context
# 20  https://w3id.org/ro/crate/1.1/context
# ...

# %%
pandas.read_json("LMS-DataStuff/trove-periodicals-data-main/titles-issues-added.ndjson", lines=True)
# Out:
#                      id                                              title  \
# 0     nla.obj-244631375  ... musical cabinet, no. 1-37 by W.H. Glen & C...
# 1     nla.obj-243252799  ... musical magazine, No. 1-89 by Nicholson, [...
# 2       nla.obj-8423556  "Coo-ee!" : the journal of the Bishops Knoll H...
# 3    nla.obj-2998991958  (Ross's) Hobart Town almanack, and Van Diemen'...
# 4    nla.obj-2998997061  (Ross's) Van Diemen's Land annual and Hobart T...
# ..                  ...                                                ...
# 944  nla.obj-3095242188  Year book of the Royal Australian Institute of...
# 945  nla.obj-3050325075                         Yesterday & most of today.
# 946  nla.obj-3095030785                                  Your home in W.A.
# 947    nla.obj-60535517                              Zhong xi jiao hui bao
# 948    nla.obj-60418801                              Zhong xi wen jian lu.
#
#                                              publisher  \
# ...

# %%
pandas.read_csv("LMS-DataStuff/issue_unmerged.csv")
# Out:
#                       id           issue_id       issue_number date_published  \
# 0        nla.obj-8423556    nla.obj-8447243  Volume 1 Number 1     1916-11-10
# 1        nla.obj-8423556    nla.obj-8452230  Volume 1 Number 2     1916-12-20
# 2        nla.obj-8423556    nla.obj-8458012  Volume 1 Number 3     1917-01-19
# 3        nla.obj-8423556    nla.obj-8465575  Volume 1 Number 4     1917-02-19
# 4        nla.obj-8423556    nla.obj-8469716  Volume 1 Number 5     1917-03-09
# ...                  ...                ...                ...            ...
# 37010  nla.obj-489106103  nla.obj-490481414        21st (2012)     2012-11-06
# 37011  nla.obj-489106103  nla.obj-490492247        22nd (2013)     2013-11-12
# 37012  nla.obj-489106103  nla.obj-490512490        23rd (2014)     2014-11-11
# 37013  nla.obj-489106103  nla.obj-490513884        24th (2015)     2015-11-11
# 37014  nla.obj-489106103  nla.obj-490602519        25th (2016)     2016-11-09
#
#        page_count
# ...

# %%
pandas.read_csv("LMS-DataStuff/titles_unmerged.csv")
# Out:
#                      id                                              title  \
# 0       nla.obj-8423556  "Coo-ee!" : the journal of the Bishops Knoll H...
# 1    nla.obj-2998991958  (Ross's) Hobart Town almanack, and Van Diemen'...
# 2    nla.obj-2998997061  (Ross's) Van Diemen's Land annual and Hobart T...
# 3      nla.obj-15956697                             14th Company magazine.
# 4     nla.obj-250818955        20 favourite & war-time camp songs [music].
# ..                  ...                                                ...
# 903    nla.obj-54933471                                            [Acts].
# 904  nla.obj-3193629693                    [Australian medical pamphlets].
# 905   nla.obj-773155481                                         [Magazine]
# 906   nla.obj-526663409                                         [Magazine]
# 907   nla.obj-489106103  [Program &] abstracts [book] : [NSW Coastal Co...
#
#                                    publisher  \
# ...

# %%
pandas.read_csv("LMS-DataStuff/periodicals_issues_insert.csv")
# Out:
#                       id                                             insert
# 0        nla.obj-8423556  [{'issue_id': 'nla.obj-8447243', 'issue_number...
# 1        nla.obj-8423556  [{'issue_id': 'nla.obj-8452230', 'issue_number...
# 2        nla.obj-8423556  [{'issue_id': 'nla.obj-8458012', 'issue_number...
# 3        nla.obj-8423556  [{'issue_id': 'nla.obj-8465575', 'issue_number...
# 4        nla.obj-8423556  [{'issue_id': 'nla.obj-8469716', 'issue_number...
# ...                  ...                                                ...
# 37010  nla.obj-489106103  [{'issue_id': 'nla.obj-490481414', 'issue_numb...
# 37011  nla.obj-489106103  [{'issue_id': 'nla.obj-490492247', 'issue_numb...
# 37012  nla.obj-489106103  [{'issue_id': 'nla.obj-490512490', 'issue_numb...
# 37013  nla.obj-489106103  [{'issue_id': 'nla.obj-490513884', 'issue_numb...
# 37014  nla.obj-489106103  [{'issue_id': 'nla.obj-490602519', 'issue_numb...
#
# [37015 rows x 2 columns]

# %%
pandas.read_csv("LMS-DataStuff/periodicals_merged.csv")
# Out:
#                       id                                              title  \
# 0        nla.obj-1037567  Anzac bulletin : issued to members of the Aust...
# 1        nla.obj-1037567  Anzac bulletin : issued to members of the Aust...
# 2        nla.obj-1037567  Anzac bulletin : issued to members of the Aust...
# 3        nla.obj-1037567  Anzac bulletin : issued to members of the Aust...
# 4        nla.obj-1037567  Anzac bulletin : issued to members of the Aust...
# ...                  ...                                                ...
# 37118  nla.obj-969917508                                            Portal.
# 37119  nla.obj-969917508                                            Portal.
# 37120  nla.obj-971558208  The progress of demobilisation and re-establis...
# 37121  nla.obj-971558208  The progress of demobilisation and re-establis...
# 37122  nla.obj-971558208  The progress of demobilisation and re-establis...
#
# ...

# %%
pandas.read_csv("LMS-DataStuff/books_deduped.csv")
# Out:
#        Text#  Type      Issued  \
# 0          1  Text  1971-12-01
# 1          2  Text  1972-12-01
# 2          3  Text  1973-11-01
# 3          4  Text  1973-11-01
# 4          5  Text  1975-12-01
# ...      ...   ...         ...
# 64780  76310  Text  2025-06-15
# 64781  76311  Text  2025-06-15
# 64782  76312  Text  2025-06-15
# 64783  76313  Text  2025-06-15
# 64784  76314  Text  2025-06-15
#
#                                                    Title Language  \
# 0      The Declaration of Independence of the United ...       en
# 1      The United States Bill of Rights\r\nThe Ten Or...       en
# 2                    John F. Kennedy's Inaugural Address       en
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en
# 4                         The United States Constitution       en
# ...                                                  ...      ...
# 64780                                         Cindrulino       eo
# ...
